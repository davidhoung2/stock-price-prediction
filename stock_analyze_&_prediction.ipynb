# %% [markdown]
# <a href="https://colab.research.google.com/github/davidhoung2/stock-price-prediction/blob/main/stock_analyze_%26_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
netflix = pd.read_csv("netflix.csv")
google = pd.read_csv("google.csv")
Amazon = pd.read_csv("Amazon.csv")
Tesla = pd.read_csv("Tesla.csv")

# %%
netflix.head()
# Out:
#          Date       High        Low       Open      Close    Volume  Adj Close
# 0  2015-01-05  49.258572  47.147144  49.258572  47.311428  18165000  47.311428
# 1  2015-01-06  47.639999  45.661430  47.347141  46.501431  16037700  46.501431
# 2  2015-01-07  47.421429  46.271427  47.347141  46.742859   9849700  46.742859
# 3  2015-01-08  47.835712  46.478573  47.119999  47.779999   9601900  47.779999
# 4  2015-01-09  48.020000  46.898571  47.631428  47.041428   9578100  47.041428

# %%
#netflix.info()

# %%
netflix = netflix.sort_values(by = 'Date', ignore_index = True)

# %%
netflix = netflix.sort_values(by = 'Date', ignore_index = True)

# %%
netflix = netflix[netflix["Date"] >= '2015-01-01'].reset_index(drop = True)
netflix = netflix[netflix["Date"] <= '2021-10-11'].reset_index(drop = True)

# %%
netflix.describe()
# Out:
#               High          Low  ...        Volume    Adj Close
# count  1705.000000  1705.000000  ...  1.705000e+03  1705.000000
# mean    280.023593   271.624938  ...  9.950784e+06   275.985543
# std     161.549806   156.937114  ...  8.128045e+06   159.299511
# min      46.785713    45.264286  ...  1.144000e+06    45.547142
# 25%     119.589996   116.190002  ...  4.992800e+06   117.680000
# 50%     291.250000   281.000000  ...  7.569300e+06   286.279999
# 75%     382.000000   370.880005  ...  1.221890e+07   377.880005
# max     646.840027   630.859985  ...  1.045009e+08   639.099976
#
# [8 rows x 6 columns]

# %%
netflix["Date"] = pd.to_datetime(netflix["Date"])

# %% [markdown]
# **[google
# ]**

# %%
google.head()
# Out:
#          Date       High        Low  ...      Close      Volume  Adj Close
# 0  2004-08-19  51.835709  47.800831  ...  49.982655  44871361.0  49.982655
# 1  2004-08-20  54.336334  50.062355  ...  53.952770  22942874.0  53.952770
# 2  2004-08-23  56.528118  54.321388  ...  54.495735  18342897.0  54.495735
# 3  2004-08-24  55.591629  51.591621  ...  52.239197  15319808.0  52.239197
# 4  2004-08-25  53.798351  51.746044  ...  52.802086   9232276.0  52.802086
#
# [5 rows x 7 columns]

# %%
#google.info()

# %%
google["Date"] = pd.to_datetime(google["Date"])

# %%
google = google.sort_values(by = 'Date', ignore_index = True)

# %%
google = google[google["Date"] >= '2015-01-01'].reset_index(drop = True)
google = google[google["Date"] <= '2021-10-11'].reset_index(drop = True)

# %%
google.describe()
# Out:
#               High          Low  ...        Volume    Adj Close
# count  1706.000000  1706.000000  ...  1.706000e+03  1706.000000
# mean   1177.401730  1155.739399  ...  1.689021e+06  1167.078174
# std     543.868451   534.609600  ...  8.192434e+05   539.594217
# min     494.618011   486.225067  ...  3.468000e+05   491.201416
# 25%     775.210007   766.476242  ...  1.204350e+06   770.880020
# 50%    1082.987488  1060.699951  ...  1.484050e+06  1073.429993
# 75%    1337.382263  1313.910034  ...  1.936500e+06  1325.275024
# max    2936.409912  2912.290039  ...  1.116490e+07  2916.840088
#
# [8 rows x 6 columns]

# %% [markdown]
# **Amazon**

# %%
Amazon.head()
# Out:
#          Date        Open        High  ...       Close   Adj Close   Volume
# 0  2015-01-02  312.579987  314.750000  ...  308.519989  308.519989  2783200
# 1  2015-01-05  307.010010  308.380005  ...  302.190002  302.190002  2774200
# 2  2015-01-06  302.239990  303.000000  ...  295.290009  295.290009  3519000
# 3  2015-01-07  297.500000  301.279999  ...  298.420013  298.420013  2640300
# 4  2015-01-08  300.320007  303.140015  ...  300.459991  300.459991  3088400
#
# [5 rows x 7 columns]

# %%
#Amazon.info()

# %%
Amazon["Date"] = pd.to_datetime(Amazon["Date"])

# %%
Amazon = Amazon.sort_values(by = 'Date', ignore_index = True)

# %%
Amazon = Amazon[Amazon["Date"] >= '2015-01-01'].reset_index(drop = True)
Amazon = Amazon[Amazon["Date"] <= '2021-10-11'].reset_index(drop = True)

# %%
google.describe()
# Out:
#               High          Low  ...        Volume    Adj Close
# count  1706.000000  1706.000000  ...  1.706000e+03  1706.000000
# mean   1177.401730  1155.739399  ...  1.689021e+06  1167.078174
# std     543.868451   534.609600  ...  8.192434e+05   539.594217
# min     494.618011   486.225067  ...  3.468000e+05   491.201416
# 25%     775.210007   766.476242  ...  1.204350e+06   770.880020
# 50%    1082.987488  1060.699951  ...  1.484050e+06  1073.429993
# 75%    1337.382263  1313.910034  ...  1.936500e+06  1325.275024
# max    2936.409912  2912.290039  ...  1.116490e+07  2916.840088
#
# [8 rows x 6 columns]

# %% [markdown]
# **Tesla**

# %%
Tesla.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %%
#Tesla.info()

# %%
Tesla["Date"] = pd.to_datetime(Tesla["Date"])

# %%
Tesla = Tesla[Tesla["Date"] >= '2015-01-01'].reset_index(drop = True)
Tesla = Tesla[Tesla["Date"] <= '2021-10-11'].reset_index(drop = True)

# %%
Tesla.describe()
# Out:
#               Open         High  ...    Adj Close        Volume
# count  1706.000000  1706.000000  ...  1706.000000  1.706000e+03
# mean    163.260742   166.618401  ...   163.355315  3.865729e+07
# std     223.276148   227.727233  ...   223.372125  2.847817e+07
# min      28.464001    30.993999  ...    28.733999  3.540000e+06
# 25%      46.253501    47.009499  ...    46.322999  2.090162e+07
# 50%      60.716002    61.705000  ...    60.856999  2.990200e+07
# 75%     101.805502   104.894498  ...   103.154001  4.510450e+07
# max     891.380005   900.400024  ...   883.090027  3.046940e+08
#
# [8 rows x 6 columns]

# %% [markdown]
# **Analyze**

# %%
Companies = [netflix,google,Amazon,Tesla]

# %%
Companies_Title = ["netflix","google","Amazon","Tesla"]

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Adj Close"])
  plt.title(Companies_Title[index])
  plt.ylabel('Adj Close')

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Volume"])
  plt.title(Companies_Title[index])
  plt.ylabel('Volume')

# %%
Moving_Average_Day = [10, 20, 50]
for Moving_Average in Moving_Average_Day:
  for company in Companies:
    column_name = f'Moving Average for {Moving_Average} days'
    company[column_name] = company["Adj Close"].rolling(Moving_Average).mean()

# %% [markdown]
# **簡單移動平均（SMA）**

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Adj Close"])
  plt.plot(company["Date"], company["Moving Average for 10 days"])
  plt.plot(company["Date"], company["Moving Average for 20 days"])
  plt.plot(company["Date"], company["Moving Average for 50 days"])
  plt.title(Companies_Title[index])
  plt.legend(("Adj Close", "Moving Average for 10 days", "Moving Average for 20 days", "Moving Average for 50 days"))

# %% [markdown]
# **Daily** **Return**

# %%
for company in Companies:
  company["Daily Return"] = company["Adj Close"].pct_change()

# %%
plt.figure(figsize=(20, 12))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  plt.plot(company["Date"], company["Daily Return"])
  plt.title(Companies_Title[index])
  plt.ylabel('Daily Return')

# %%
import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize=(20, 15))
for index, company in enumerate(Companies):
  plt.subplot(3, 2, index + 1)
  sns.distplot(company["Daily Return"].dropna(), color = "purple")
  plt.title(Companies_Title[index])

# %%
print("Kurtosis Value")
for index, company in enumerate(Companies):
  print(f'{Companies_Title[index]}: {company["Daily Return"].kurtosis()}')
# Out:
# Kurtosis Value
# netflix: 8.169948435103791
# google: 9.961838326420834
# Amazon: 7.255268251807761
# Tesla: 5.975682455151341

# %%
Companies_returns = pd.DataFrame()
Companies_returns["netflix"] = netflix["Adj Close"]
Companies_returns["google"] = google["Adj Close"]
Companies_returns["Amazon"] = Amazon["Adj Close"]
Companies_returns["Tesla"] = Tesla["Adj Close"]
'''

Companies_returns["netflix"] = netflix["Adj Close"]
Companies_returns["Amazon"] = Amazon["Adj Close"]

'''
Companies_returns.head()
# Out:
#      netflix      google      Amazon      Tesla
# 0  47.311428  523.373108  308.519989  43.862000
# 1  46.501431  512.463013  302.190002  42.018002
# 2  46.742859  500.585632  295.290009  42.256001
# 3  47.779999  499.727997  298.420013  42.189999
# 4  47.041428  501.303680  300.459991  42.124001

# %%
Companies_Daily_returns = Companies_returns.pct_change()
Companies_Daily_returns.head()
# Out:
#     netflix    google    Amazon     Tesla
# 0       NaN       NaN       NaN       NaN
# 1 -0.017121 -0.020846 -0.020517 -0.042041
# 2  0.005192 -0.023177 -0.022833  0.005664
# 3  0.022188 -0.001713  0.010600 -0.001562
# 4 -0.015458  0.003153  0.006836 -0.001564

# %% [markdown]
# **correlation**

# %%
sns.heatmap(Companies_returns.corr(), annot=True, cmap="YlGnBu")

# %%
sns.heatmap(Companies_Daily_returns.corr(), annot=True, cmap="YlGnBu")

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
Returns = Companies_Daily_returns.dropna()

plt.figure(figsize=(20, 5))
plt.scatter(Returns.mean(), Returns.std())
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(Companies_Title, Returns.mean(), Returns.std()):
    plt.annotate(label, xy = (x, y), xytext = (10, 0), textcoords = 'offset points')

# %% [markdown]
# **>deep learning**

# %%
def Dataset(Data, Date):

  Train_Data = Data['Adj Close'][Data['Date'] < Date].to_numpy()
  Data_Train = []
  Data_Train_X = []
  Data_Train_Y = []
  #1周5個工作日
  for i in range(0, len(Train_Data), 5):
    try:
      Data_Train.append(Train_Data[i : i + 5])
    except:
      pass

  if len(Data_Train[-1]) < 5:
    Data_Train.pop(-1)
  
  Data_Train_X = Data_Train[0 : -1]
  Data_Train_X = np.array(Data_Train_X)
  Data_Train_X = Data_Train_X.reshape((-1, 5, 1))
  Data_Train_Y = Data_Train[1 : len(Data_Train)]
  Data_Train_Y = np.array(Data_Train_Y)
  Data_Train_Y = Data_Train_Y.reshape((-1, 5, 1))


  Test_Data = Data['Adj Close'][Data['Date'] >= Date].to_numpy()
  Data_Test = []
  Data_Test_X = []
  Data_Test_Y = []
  for i in range(0, len(Test_Data), 5):
    try:
      Data_Test.append(Test_Data[i : i + 5])
    except:
      pass

  if len(Data_Test[-1]) < 5:
    Data_Test.pop(-1)
  
  Data_Test_X = Data_Test[0 : -1]
  Data_Test_X = np.array(Data_Test_X)
  Data_Test_X = Data_Test_X.reshape((-1, 5, 1))
  Data_Test_Y = Data_Test[1 : len(Data_Test)]
  Data_Test_Y = np.array(Data_Test_Y)
  Data_Test_Y = Data_Test_Y.reshape((-1, 5, 1))

  return Data_Train_X, Data_Train_Y, Data_Test_X, Data_Test_Y

# %%
def Model():
  model = tf.keras.models.Sequential([
                      tf.keras.layers.LSTM(200, input_shape = (5, 1), activation = tf.nn.leaky_relu, return_sequences = True),
                      tf.keras.layers.LSTM(200, activation = tf.nn.leaky_relu),
                      tf.keras.layers.Dense(200, activation = tf.nn.leaky_relu),
                      tf.keras.layers.Dense(100, activation = tf.nn.leaky_relu),
                      tf.keras.layers.Dense(50, activation = tf.nn.leaky_relu),
                      tf.keras.layers.Dense(5, activation = tf.nn.leaky_relu)
                      ])
  return model

# %%
model = Model()

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 5, 200)            161600
#
#  lstm_1 (LSTM)               (None, 200)               320800
#
#  dense (Dense)               (None, 200)               40200
#
#  dense_1 (Dense)             (None, 100)               20100
#
#  dense_2 (Dense)             (None, 50)                5050
#
#  dense_3 (Dense)             (None, 5)                 255
#
# ...
# Total params: 548,005
# Trainable params: 548,005
# Non-trainable params: 0
# _________________________________________________________________

# %%
def scheduler(epoch):
  warmup_steps = 150
  initial_lrate = 1e-5
  #warm up
  if epoch <= 150:
    lrate = 1e-5 * (epoch / warmup_steps) 
  
  elif epoch <= 400:
    k = 0.01
    lrate = initial_lrate * math.exp(-k * (epoch - 150))
  else:
    lrate = 9e-7

  
  return lrate

# %%
epochs = [i for i in range(1, 1001, 1)]
lrate = [scheduler(i) for i in range(1, 1001, 1)]
plt.xlabel("epcho")
plt.ylabel("learning rate")
plt.plot(epochs, lrate)

# %%
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %% [markdown]
# **Netflix train**

# %%
netflix_Date = '2021-06-15'
netflix_Train_X, netflix_Train_Y, netflix_Test_X, netflix_Test_Y = Dataset(netflix, netflix_Date)

# %%
netflix_Model = Model()

# %%
netflix_Model.compile(optimizer = tf.keras.optimizers.Adam(), loss = 'mse', metrics = tf.keras.metrics.RootMeanSquaredError())

# %%
netflix_hist = netflix_Model.fit(netflix_Train_X, netflix_Train_Y, epochs = 1000, validation_data = (netflix_Test_X, netflix_Test_Y), callbacks=[callback])

# %%
history_dict = netflix_hist.history

loss = history_dict["loss"]
root_mean_squared_error = history_dict["root_mean_squared_error"]
val_loss = history_dict["val_loss"]
val_root_mean_squared_error = history_dict["val_root_mean_squared_error"]

epochs = range(1, len(loss) + 1)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

fig.set_figheight(5)
fig.set_figwidth(15)

ax1.plot(epochs, loss, label = 'Training Loss')
ax1.plot(epochs, val_loss, label = 'Validation Loss')
ax1.set(xlabel = "Epochs", ylabel = "Loss")
ax1.legend()

ax2.plot(epochs, root_mean_squared_error, label = "Training Root Mean Squared Error")
ax2.plot(epochs, val_root_mean_squared_error, label = "Validation Root Mean Squared Error")
ax2.set(xlabel = "Epochs", ylabel = "Loss")
ax2.legend()

plt.show()

# %%
netflix_prediction = netflix_Model.predict(netflix_Test_X)

# %%
plt.figure(figsize=(10, 5))
plt.plot(netflix['Date'][netflix['Date'] < '2021-06-25'], netflix['Adj Close'][netflix['Date'] < '2021-06-25'], label = 'Training')
plt.plot(netflix['Date'][netflix['Date'] >= '2021-06-10'], netflix['Adj Close'][netflix['Date'] >= '2021-06-10'], label = 'Testing')
plt.plot(netflix['Date'][netflix['Date'] >= '2021-06-25'], netflix_prediction.reshape(-1), label = 'Predictions')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend(loc = 'best')

# %% [markdown]
# **均方根誤差(RMSE)**
#
# **平均絕對百分比誤差(MAPE)**

# %%
rmse = math.sqrt(mean_squared_error(netflix_Test_Y.reshape(-1, 5), netflix_prediction))
mape = np.mean(np.abs(netflix_prediction - netflix_Test_Y.reshape(-1, 5))/np.abs(netflix_Test_Y.reshape(-1, 5)))*100
print(f'RMSE: {rmse}')
print(f'MAPE: {mape} %')
# Out:
# RMSE: 17.904191193967847
# MAPE: 2.22996091648307 %

# %% [markdown]
# **Amazon Train**

# %%
Amazon_Date = '2021-06-15'
Amazon_Train_X, Amazon_Train_Y, Amazon_Test_X, Amazon_Test_Y = Dataset(Amazon, Amazon_Date)

# %%
Amazon_Model = Model()

# %%
Amazon_Model.compile(optimizer = tf.keras.optimizers.Adam(), loss = 'mse', metrics = tf.keras.metrics.RootMeanSquaredError())

# %%
Amazon_hist = Amazon_Model.fit(Amazon_Train_X, Amazon_Train_Y, epochs = 1000, validation_data = (Amazon_Test_X, Amazon_Test_Y), callbacks=[callback])

# %%
history_dict = Amazon_hist.history

loss = history_dict["loss"]
root_mean_squared_error = history_dict["root_mean_squared_error"]
val_loss = history_dict["val_loss"]
val_root_mean_squared_error = history_dict["val_root_mean_squared_error"]

epochs = range(1, len(loss) + 1)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

fig.set_figheight(5)
fig.set_figwidth(15)

ax1.plot(epochs, loss, label = "Training Loss")
ax1.plot(epochs, val_loss, label = "Validation Loss")
ax1.set(xlabel = "Epochs", ylabel = "Loss")
ax1.legend()

ax2.plot(epochs, root_mean_squared_error, label = "Training Root Mean Squared Error")
ax2.plot(epochs, val_root_mean_squared_error, label = "Validation Root Mean Squared Error")
ax2.set(xlabel = "Epochs", ylabel = "Loss")
ax2.legend()

plt.show()

# %%
Amazon_prediction = Amazon_Model.predict(Amazon_Test_X)

# %%
plt.figure(figsize=(10, 5))
plt.plot(Amazon['Date'][Amazon['Date'] < '2021-06-25'], Amazon['Adj Close'][Amazon['Date'] < '2021-06-25'], label = 'Training')
plt.plot(Amazon['Date'][Amazon['Date'] >= '2021-06-10'], Amazon['Adj Close'][Amazon['Date'] >= '2021-06-10'], label = 'Testing')
plt.plot(Amazon['Date'][Amazon['Date'] >= '2021-06-25'], Amazon_prediction.reshape(-1), label = 'Predictions')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend(loc = 'best')

# %%
rmse = math.sqrt(mean_squared_error(Amazon_Test_Y.reshape(-1, 5), Amazon_prediction))
mape = np.mean(np.abs(Amazon_prediction - Amazon_Test_Y.reshape(-1, 5))/np.abs(Amazon_Test_Y.reshape(-1, 5)))*100
print(f'RMSE: {rmse}')
print(f'MAPE: {mape}% ')
# Out:
# RMSE: 104.9740532443128
# MAPE: 2.4166268304806455%

# %% [markdown]
# **Tesla train**

# %%
Tesla_Date = '2021-06-15'
Tesla_Train_X, Tesla_Train_Y, Tesla_Test_X, Tesla_Test_Y = Dataset(Tesla, Tesla_Date)

# %%
Tesla_Model = Model()

# %%
Tesla_Model.compile(optimizer = tf.keras.optimizers.Adam(), loss = 'mse', metrics = tf.keras.metrics.RootMeanSquaredError())

# %%
Tesla_hist = Tesla_Model.fit(Tesla_Train_X, Tesla_Train_Y, epochs = 1000, validation_data = (Tesla_Test_X, Tesla_Test_Y), callbacks=[callback])

# %%
history_dict = Tesla_hist.history

loss = history_dict["loss"]
root_mean_squared_error = history_dict["root_mean_squared_error"]
val_loss = history_dict["val_loss"]
val_root_mean_squared_error = history_dict["val_root_mean_squared_error"]

epochs = range(1, len(loss) + 1)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

fig.set_figheight(5)
fig.set_figwidth(15)

ax1.plot(epochs, loss, label = "Training Loss")
ax1.plot(epochs, val_loss, label = "Validation Loss")
ax1.set(xlabel = "Epochs", ylabel = "Loss")
ax1.legend()

ax2.plot(epochs, root_mean_squared_error, label = "Training Root Mean Squared Error")
ax2.plot(epochs, val_root_mean_squared_error, label = "Validation Root Mean Squared Error")
ax2.set(xlabel = "Epochs", ylabel = "Loss")
ax2.legend()

plt.show()

# %%
Tesla_prediction = Tesla_Model.predict(Tesla_Test_X)

# %%
plt.figure(figsize=(10, 5))
plt.plot(Tesla['Date'][Tesla['Date'] < '2021-06-25'], Tesla['Adj Close'][Tesla['Date'] < '2021-06-25'], label = 'Training')
plt.plot(Tesla['Date'][Tesla['Date'] >= '2021-06-10'], Tesla['Adj Close'][Tesla['Date'] >= '2021-06-10'], label = 'Testing')
plt.plot(Tesla['Date'][Tesla['Date'] >= '2021-06-25'], Tesla_prediction.reshape(-1), label = 'Predictions')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend(loc = 'best')

# %%
rmse = math.sqrt(mean_squared_error(Tesla_Test_Y.reshape(-1, 5), Tesla_prediction))
mape = np.mean(np.abs(Tesla_prediction - Tesla_Test_Y.reshape(-1, 5))/np.abs(Tesla_Test_Y.reshape(-1, 5)))*100
print(f'RMSE: {rmse}')
print(f'MAPE: {mape}% ')
# Out:
# RMSE: 29.76287513978468
# MAPE: 3.2131938232249864%

# %% [markdown]
# **google train**

# %%
google_Date = '2021-06-15'
google_Train_X, google_Train_Y, google_Test_X, google_Test_Y = Dataset(google, google_Date)

# %%
google_Model = Model()

# %%
google_Model.compile(optimizer = tf.keras.optimizers.Adam(), loss = 'mse', metrics = tf.keras.metrics.RootMeanSquaredError())

# %%
google_hist = google_Model.fit(google_Train_X, google_Train_Y, epochs = 1000, validation_data = (google_Test_X, google_Test_Y), callbacks=[callback])

# %%
history_dict = google_hist.history

loss = history_dict["loss"]
root_mean_squared_error = history_dict["root_mean_squared_error"]
val_loss = history_dict["val_loss"]
val_root_mean_squared_error = history_dict["val_root_mean_squared_error"]

epochs = range(1, len(loss) + 1)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

fig.set_figheight(5)
fig.set_figwidth(15)

ax1.plot(epochs, loss, label = "Training Loss")
ax1.plot(epochs, val_loss, label = "Validation Loss")
ax1.set(xlabel = "Epochs", ylabel = "Loss")
ax1.legend()

ax2.plot(epochs, root_mean_squared_error, label = "Training Root Mean Squared Error")
ax2.plot(epochs, val_root_mean_squared_error, label = "Validation Root Mean Squared Error")
ax2.set(xlabel = "Epochs", ylabel = "Loss")
ax2.legend()

plt.show()

# %%
google_prediction = google_Model.predict(google_Test_X)

# %%
plt.figure(figsize=(10, 5))
plt.plot(google['Date'][google['Date'] < '2021-06-25'], google['Adj Close'][google['Date'] < '2021-06-25'], label = 'Training')
plt.plot(google['Date'][google['Date'] >= '2021-06-10'], google['Adj Close'][google['Date'] >= '2021-06-10'], label = 'Testing')
plt.plot(google['Date'][google['Date'] >= '2021-06-25'], google_prediction.reshape(-1), label = 'Predictions')
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.legend(loc = 'best')

# %%
rmse = math.sqrt(mean_squared_error(google_Test_Y.reshape(-1, 5), google_prediction))
mape = np.mean(np.abs(google_prediction - google_Test_Y.reshape(-1, 5))/np.abs(google_Test_Y.reshape(-1, 5)))*100
print(f'RMSE: {rmse}')
print(f'MAPE: {mape}% ')
# Out:
# RMSE: 77.6125292803508
# MAPE: 2.155821981127189%
